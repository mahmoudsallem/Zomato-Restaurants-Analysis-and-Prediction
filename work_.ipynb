# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import datasist as ds
import plotly as pt

# %%
df = pd.read_csv('zomato.csv')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# # Use datasist lib to get the :
# - First five data points
# - Random five data points
# - Last five data points
# - The shape of data set
# - Size of  data set
# - Data Types of all features
# - Numerical Features in Data set
# - Categorical Features in Data set
# - Description of Categorical Features
# - Unique class Count of Categorical features
# - Missing Values in Data

# %%
ds.structdata.describe(df)
# Out:
# First five data points
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %% [markdown]
# ## get the unique values of rest_type
# - there are missing data in rest_type 'nan'

# %%
for cat in ["rest_type"]:
    print(cat)
    print('---------')
    for val in df[cat].unique():
        print(f'  - {val}')
    print('-'*80)
# Out:
# rest_type
# ---------
#   - Casual Dining
#   - Cafe, Casual Dining
#   - Quick Bites
#   - Casual Dining, Cafe
#   - Cafe
#   - Quick Bites, Cafe
#   - Cafe, Quick Bites
#   - Delivery
#   - Mess
#   - Dessert Parlor
#   - Bakery, Dessert Parlor
#   - Pub
#   - Bakery
#   - Takeaway, Delivery
#   - Fine Dining
#   - Beverage Shop
#   - Sweet Shop
#   - Bar
#   - Beverage Shop, Quick Bites
#   - Confectionery
#   - Quick Bites, Beverage Shop
#   - Dessert Parlor, Sweet Shop
#   - Bakery, Quick Bites
#   - Sweet Shop, Quick Bites
#   - Kiosk
#   - Food Truck
#   - Quick Bites, Dessert Parlor
#   - Beverage Shop, Dessert Parlor
#   - Takeaway
#   - Pub, Casual Dining
#   - Casual Dining, Bar
#   - Dessert Parlor, Beverage Shop
#   - Quick Bites, Bakery
#   - Dessert Parlor, Quick Bites
#   - Microbrewery, Casual Dining
#   - Lounge
#   - Bar, Casual Dining
#   - Food Court
#   - Cafe, Bakery
#   - nan
#   - Dhaba
#   - Quick Bites, Sweet Shop
#   - Microbrewery
# ...

# %% [markdown]
# ## Top 5 Restaurants  address in zomato

# %%
df['address'].value_counts().head()
# Out:
# Delivery Only                                           128
# 14th Main, 4th Sector, HSR, Bangalore                    71
# The Ritz-Carlton, 99, Residency Road, Bangalore          61
# Citrus Hotels, 34, Cunningham Road, Bangalore            53
# Conrad Bengaluru, Kensington Road, Ulsoor, Bangalore     49
# Name: address, dtype: int64

# %%
df['online_order'].value_counts()
# Out:
# Yes    30444
# No     21273
# Name: online_order, dtype: int64

# %% [markdown]
# ## There are alot of people take order online

# %%
plt.figure(figsize=[10,10])
sns.countplot(x='online_order', data=df)
# Out:
# <AxesSubplot:xlabel='online_order', ylabel='count'>

# %% [markdown]
# ## There aren't many people book tables in  zomato

# %%
plt.figure(figsize=[10,10])
sns.countplot(x='book_table', data=df)
# Out:
# <AxesSubplot:xlabel='book_table', ylabel='count'>

# %% [markdown]
# ## Try to splite rate

# %%
df['rate'][0].split('/')[0]
# Out:
# '4.1'

# %% [markdown]
# ## there are error in the column use try and except to avoid the error

# %%
def spl (x):
    try:
        return x.split('/')[0]
    except:
        pass

# %%
df['rate'] = df['rate'].apply(spl)

# %% [markdown]
# ## know the error values in the rate column
# - NEW
# - None
# - -

# %%
for cat in ["rate"]:
    print(cat)
    print('---------')
    for val in df[cat].unique():
        print(f'  - {val}')
    print('-'*80)
# Out:
# rate
# ---------
#   - 4.1
#   - 3.8
#   - 3.7
#   - 3.6
#   - 4.6
#   - 4.0
#   - 4.2
#   - 3.9
#   - 3.1
#   - 3.0
#   - 3.2
#   - 3.3
#   - 2.8
#   - 4.4
#   - 4.3
#   - NEW
#   - 2.9
#   - 3.5
#   - None
#   - 2.6
#   - 3.8
#   - 3.4
#   - 4.5
#   - 2.5
#   - 2.7
#   - 4.7
#   - 2.4
#   - 2.2
#   - 2.3
#   - 3.4
#   - -
#   - 3.6
#   - 4.8
#   - 3.9
#   - 4.2
#   - 4.0
#   - 4.1
#   - 3.7
#   - 3.1
#   - 2.9
#   - 3.3
#   - 2.8
#   - 3.5
#   - 2.7
#   - 2.5
#   - 3.2
#   - 2.6
#   - 4.5
#   - 4.3
#   - 4.4
#   - 4.9
#   - 2.1
#   - 2.0
#   - 1.8
#   - 4.6
#   - 4.9
#   - 3.0
#   - 4.8
#   - 2.3
#   - 4.7
#   - 2.4
#   - 2.1
#   - 2.2
#   - 2.0
#   - 1.8
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Top 5 Restaurants type

# %%
df['rest_type'].value_counts().head(5)
# Out:
# Quick Bites       19132
# Casual Dining     10330
# Cafe               3732
# Delivery           2604
# Dessert Parlor     2263
# Name: rest_type, dtype: int64

# %% [markdown]
# ## there are alot of Restaurants dontwant to show the menus of them

# %%
df['menu_item'].value_counts().head(1)
# Out:
# []    39617
# Name: menu_item, dtype: int64

# %%
df.drop('menu_item',axis=1,inplace=True)

# %% [markdown]
# ## there are alot of dish liked missing from columns 54.3% missing

# %%
df['dish_liked'].value_counts()
# Out:
# Biryani                                                                                              182
# Chicken Biryani                                                                                       73
# Friendly Staff                                                                                        69
# Waffles                                                                                               68
# Paratha                                                                                               57
#                                                                                                     ...
# Butter Chicken, Shawarma Roll, Chicken Shawarama, Chicken Grill, Rolls, Al Faham Chicken, Biryani      1
# Filter Coffee, Sandwich, Bonda, Vada, Masala Dosa, Salad, Aloo Curry                                   1
# Burgers, Fries, Jumbo Royale Burger, Salads, Peri Peri Chicken Salad, Potato Wedges, Rolls             1
# ...

# %%
len(df['dish_liked'].value_counts())
# Out:
# 5271

# %% [markdown]
# ## you can use imputation if domain knowledge want to use it
# - i want to drop it

# %%
df.drop('dish_liked',axis=1,inplace=True)

# %%
df['listed_in(city)'].value_counts()
# Out:
# BTM                      3279
# Koramangala 7th Block    2938
# Koramangala 5th Block    2836
# Koramangala 4th Block    2779
# Koramangala 6th Block    2623
# Jayanagar                2371
# JP Nagar                 2096
# Indiranagar              1860
# Church Street            1827
# MG Road                  1811
# Brigade Road             1769
# Lavelle Road             1744
# HSR                      1741
# Marathahalli             1659
# Residency Road           1620
# Whitefield               1620
# Bannerghatta Road        1617
# Brookefield              1518
# Old Airport Road         1425
# Kammanahalli             1329
# Kalyan Nagar             1309
# Basavanagudi             1266
# Sarjapur Road            1261
# Electronic City          1229
# Bellandur                1227
# Frazer Town              1185
# Malleshwaram             1096
# Rajajinagar              1079
# Banashankari              863
# New BEL Road              740
# Name: listed_in(city), dtype: int64

# %% [markdown]
# # top 5 plases in the Bangalore
# - **BTM**
#
# - **Koramangala 7th Block**
#
# - **Koramangala 5th Block**
#
# - **Koramangala 4th Block**
#
# - **Koramangala 6th Block**

# %%
plt.figure(figsize=[15,15])
sns.countplot(y='listed_in(city)', data=df, palette='viridis')
# Out:
# <AxesSubplot:xlabel='count', ylabel='listed_in(city)'>

# %% [markdown]
# ## show the top iteam in the [cuisines ,  approx_cost(for two people)] columns

# %%
df['cuisines'].value_counts().head(15)
# Out:
# North Indian                           2913
# North Indian, Chinese                  2385
# South Indian                           1828
# Biryani                                 918
# Bakery, Desserts                        911
# Fast Food                               803
# Desserts                                766
# Cafe                                    756
# South Indian, North Indian, Chinese     726
# Bakery                                  651
# Chinese                                 556
# Ice Cream, Desserts                     417
# Chinese, North Indian                   415
# Mithai, Street Food                     372
# Desserts, Ice Cream                     354
# Name: cuisines, dtype: int64

# %%
df['approx_cost(for two people)'].value_counts().head(20)
# Out:
# 300      7576
# 400      6562
# 500      4980
# 200      4857
# 600      3714
# 250      2959
# 800      2285
# 150      2066
# 700      1948
# 350      1763
# 1,000    1637
# 450      1417
# 1,200     993
# 100       993
# 1,500     971
# 650       776
# 550       761
# 750       758
# 900       700
# 1,300     516
# Name: approx_cost(for two people), dtype: int64

# %% [markdown]
# ## show the max and min value in the approx_cost(for two people) column

# %%
df['approx_cost(for two people)'].value_counts().agg(max)
# Out:
# 7576

# %%
df['approx_cost(for two people)'].value_counts().agg(min)
# Out:
# 1

# %% [markdown]
# ## drop values i think it is useless

# %%
df.drop('reviews_list',axis=1,inplace=True)

# %%
df.drop(['url','address','name'],axis=1,inplace=True)

# %%
df.drop('phone',axis=1,inplace=True)

# %%
df
# Out:
#       online_order book_table  rate  votes                    location  \
# 0              Yes        Yes   4.1    775                Banashankari
# 1              Yes         No   4.1    787                Banashankari
# 2              Yes         No   3.8    918                Banashankari
# 3               No         No   3.7     88                Banashankari
# 4               No         No   3.8    166                Basavanagudi
# ...            ...        ...   ...    ...                         ...
# 51712           No         No  3.6      27                  Whitefield
# 51713           No         No  None      0                  Whitefield
# 51714           No         No  None      0                  Whitefield
# 51715           No        Yes  4.3     236  ITPL Main Road, Whitefield
# 51716           No         No  3.4      13  ITPL Main Road, Whitefield
#
#                  rest_type                                cuisines  \
# ...

# %% [markdown]
# ## convert  [rate , approx_cost(for two people)] to numeric to handel it

# %%
df['rate'] = pd.to_numeric(df['rate'],errors = 'coerce')

# %%
df['approx_cost(for two people)'] = pd.to_numeric(df['approx_cost(for two people)'],errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   online_order                 51717 non-null  object
#  1   book_table                   51717 non-null  object
#  2   rate                         41665 non-null  float64
#  3   votes                        51717 non-null  int64
#  4   location                     51696 non-null  object
#  5   rest_type                    51490 non-null  object
#  6   cuisines                     51672 non-null  object
#  7   approx_cost(for two people)  44454 non-null  float64
#  8   listed_in(type)              51717 non-null  object
#  9   listed_in(city)              51717 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 3.9+ MB

# %% [markdown]
# ## show the outliers
# - The oltliers in approx_cost(for two people) is upper 900
#
# - The oltliers in rate is down 2.5
#
# - The oltliers in votes is terrible

# %%
sns.boxplot(x='approx_cost(for two people)', data=df)
sns.stripplot(x='approx_cost(for two people)', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='approx_cost(for two people)'>

# %%
sns.boxplot(x='rate', data=df)
sns.stripplot(x='rate', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='rate'>

# %%
sns.boxplot(x='votes', data=df)
sns.stripplot(x='votes', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='votes'>

# %% [markdown]
# ## number of missing data and the values of it
# - rate : 10052
# - approx_cost(for two people) : 7263
# - cuisines : 45
# - rest_type : 227
# - location : 21

# %%
df[df['rate'].isna()]
# Out:
#       online_order book_table  rate  votes      location           rest_type  \
# 72              No         No   NaN      0  Banashankari         Quick Bites
# 75              No         No   NaN      0  Banashankari  Takeaway, Delivery
# 84              No         No   NaN      0  Banashankari         Quick Bites
# 90              No         No   NaN      0  Banashankari            Delivery
# 91              No         No   NaN      0  Banashankari  Takeaway, Delivery
# ...            ...        ...   ...    ...           ...                 ...
# 51644           No         No   NaN      0   Brookefield         Quick Bites
# 51675           No         No   NaN      0    Whitefield                 Bar
# 51710           No         No   NaN      0    Whitefield                 Bar
# 51713           No         No   NaN      0    Whitefield                 Bar
# 51714           No         No   NaN      0    Whitefield                 Bar
#
# ...

# %%
df[df['approx_cost(for two people)'].isna()]
# Out:
#       online_order book_table  rate  votes                    location  \
# 67              No         No   4.1    868                Banashankari
# 119             No         No   3.1     30                Banashankari
# 166            Yes        Yes   4.1    364                   Jayanagar
# 207            Yes        Yes   4.1   2339                   Jayanagar
# 217            Yes        Yes   4.3   1129                   Jayanagar
# ...            ...        ...   ...    ...                         ...
# 51708           No         No   2.8    161                  Whitefield
# 51712           No         No   3.6     27                  Whitefield
# 51714           No         No   NaN      0                  Whitefield
# 51715           No        Yes   4.3    236  ITPL Main Road, Whitefield
# 51716           No         No   3.4     13  ITPL Main Road, Whitefield
#
#                 rest_type                                           cuisines  \
# ...

# %%
df[df['cuisines'].isna()]
# Out:
#       online_order book_table  rate  votes            location  \
# 438            Yes         No   NaN      0        Banashankari
# 440            Yes         No   3.3      4  Kumaraswamy Layout
# 759            Yes         No   NaN      0        Banashankari
# 1662            No         No   NaN      0                 NaN
# 4037           Yes         No   NaN      0        Marathahalli
# 6887           Yes         No   3.6      9          Whitefield
# 6897           Yes         No   NaN      0          Whitefield
# 7277            No         No   NaN      0          Whitefield
# 7555           Yes         No   NaN      0        Marathahalli
# 9874            No         No   NaN      0                 NaN
# 13591          Yes         No   NaN      0     Electronic City
# 13693           No         No   NaN      0                 NaN
# 16351           No         No   NaN      0                 NaN
# 22236          Yes         No   3.3      4  Kumaraswamy Layout
# ...

# %%
df[df['rest_type'].isna()]
# Out:
#       online_order book_table  rate  votes           location rest_type  \
# 999            Yes         No   3.5    269                BTM       NaN
# 1300           Yes         No   3.0      7           JP Nagar       NaN
# 1376           Yes         No   3.6     15                BTM       NaN
# 1565            No         No   NaN      0  Bannerghatta Road       NaN
# 1637            No         No   2.4    392  Bannerghatta Road       NaN
# ...            ...        ...   ...    ...                ...       ...
# 50978           No         No   NaN      0         Whitefield       NaN
# 51130          Yes         No   NaN      0         Whitefield       NaN
# 51195          Yes         No   3.2    202         Whitefield       NaN
# 51294           No         No   NaN      0         Whitefield       NaN
# 51303          Yes         No   NaN      0         Whitefield       NaN
#
#                                                cuisines  \
# ...

# %%
df[df['location'].isna()]
# Out:
#       online_order book_table  rate  votes location rest_type cuisines  \
# 1662            No         No   NaN      0      NaN       NaN      NaN
# 9874            No         No   NaN      0      NaN       NaN      NaN
# 13693           No         No   NaN      0      NaN       NaN      NaN
# 16351           No         No   NaN      0      NaN       NaN      NaN
# 26432           No         No   NaN      0      NaN       NaN      NaN
# 26519           No         No   NaN      0      NaN       NaN      NaN
# 27672           No         No   NaN      0      NaN       NaN      NaN
# 28611           No         No   NaN      0      NaN       NaN      NaN
# 29298           No         No   NaN      0      NaN       NaN      NaN
# 30604           No         No   NaN      0      NaN       NaN      NaN
# 31400           No         No   NaN      0      NaN       NaN      NaN
# 32131           No         No   NaN      0      NaN       NaN      NaN
# ...

# %% [markdown]
# ## there are no missing data in [votes , listed_in(city) , listed_in(type) , online_order , book_table ] columns

# %%
df[df['votes'].isna()]
# Out:
# Empty DataFrame
# Columns: [online_order, book_table, rate, votes, location, rest_type, cuisines, approx_cost(for two people), listed_in(type), listed_in(city)]
# Index: []

# %%
df[df['listed_in(city)'].isna()]
# Out:
# Empty DataFrame
# Columns: [online_order, book_table, rate, votes, location, rest_type, cuisines, approx_cost(for two people), listed_in(type), listed_in(city)]
# Index: []

# %%
df[df['listed_in(type)'].isna()]
# Out:
# Empty DataFrame
# Columns: [online_order, book_table, rate, votes, location, rest_type, cuisines, approx_cost(for two people), listed_in(type), listed_in(city)]
# Index: []

# %%
df[df['online_order'].isna()]
# Out:
# Empty DataFrame
# Columns: [online_order, book_table, rate, votes, location, rest_type, cuisines, approx_cost(for two people), listed_in(type), listed_in(city)]
# Index: []

# %%
df[df['book_table'].isna()]
# Out:
# Empty DataFrame
# Columns: [online_order, book_table, rate, votes, location, rest_type, cuisines, approx_cost(for two people), listed_in(type), listed_in(city)]
# Index: []

# %%
df.dropna()
# Out:
#       online_order book_table  rate  votes      location            rest_type  \
# 0              Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1              Yes         No   4.1    787  Banashankari        Casual Dining
# 2              Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3               No         No   3.7     88  Banashankari          Quick Bites
# 4               No         No   3.8    166  Basavanagudi        Casual Dining
# ...            ...        ...   ...    ...           ...                  ...
# 51645          Yes         No   3.6     49   Brookefield          Quick Bites
# 51674           No         No   3.7     34    Whitefield   Casual Dining, Bar
# 51677           No         No   2.5     81    Whitefield   Casual Dining, Bar
# 51709           No         No   3.7     34    Whitefield   Casual Dining, Bar
# 51711           No         No   2.5     81    Whitefield   Casual Dining, Bar
#
# ...

# %% [markdown]
# ## cane use KNN imputer and SimpleImputer or drop missing data for [cuisines , rest_type ] columns

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
df.isnull().mean(axis=0).plot.barh()
plt.title("Ratio of missing values per columns")
# Out:
# Text(0.5, 1.0, 'Ratio of missing values per columns')

# %%
df['rate'].replace('NEW',0,inplace=True)
df['rate'].replace('-',0,inplace=True)

# %%
df['rate'] =df['rate'].apply(lambda x:1 if x>3.7 else 0)

# %%
df['book_table'] = df['book_table'].apply(lambda x : 1 if x == "Yes" else 0)

# %%
df['online_order'] = df['online_order'].apply(lambda x : 1 if x == "Yes" else 0)

# %%
df
# Out:
#        online_order  book_table  rate  votes                    location  \
# 0                 1           1     1    775                Banashankari
# 1                 1           0     1    787                Banashankari
# 2                 1           0     1    918                Banashankari
# 3                 0           0     0     88                Banashankari
# 4                 0           0     1    166                Basavanagudi
# ...             ...         ...   ...    ...                         ...
# 51712             0           0     0     27                  Whitefield
# 51713             0           0     0      0                  Whitefield
# 51714             0           0     0      0                  Whitefield
# 51715             0           1     1    236  ITPL Main Road, Whitefield
# 51716             0           0     0     13  ITPL Main Road, Whitefield
#
#                  rest_type                                cuisines  \
# ...

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer()

# %%
df['rate'] = imputer.fit_transform(df[['rate']])
df['approx_cost(for two people)'] = imputer.fit_transform(df[['approx_cost(for two people)']])

df['approx_cost(for two people)'].isnull().sum()
df['rate'].isnull().sum()
# Out:
# 0

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='most_frequent')

# %%
df['cuisines'] = imputer.fit_transform(df[['cuisines']])
df['rest_type'] = imputer.fit_transform(df[['rest_type']])
df['location'] = imputer.fit_transform(df[['location']])

df['rest_type'].isnull().sum()
df['cuisines'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# cuisines                       0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df
# Out:
#        online_order  book_table  rate  votes                    location  \
# 0                 1           1   1.0    775                Banashankari
# 1                 1           0   1.0    787                Banashankari
# 2                 1           0   1.0    918                Banashankari
# 3                 0           0   0.0     88                Banashankari
# 4                 0           0   1.0    166                Basavanagudi
# ...             ...         ...   ...    ...                         ...
# 51712             0           0   0.0     27                  Whitefield
# 51713             0           0   0.0      0                  Whitefield
# 51714             0           0   0.0      0                  Whitefield
# 51715             0           1   1.0    236  ITPL Main Road, Whitefield
# 51716             0           0   0.0     13  ITPL Main Road, Whitefield
#
#                  rest_type                                cuisines  \
# ...

# %%
df['online_order'] = pd.to_numeric(df['online_order'],errors = 'coerce')
df['book_table'] = pd.to_numeric(df['book_table'],errors = 'coerce')

# %%
df = pd.get_dummies(df, columns=['location', 'rest_type','cuisines','listed_in(type)','listed_in(city)'], drop_first=True)

# %%
x = df.drop(['rate'],axis=1)
y= df[['rate']]

# %% [markdown]
# ## use pycaret automl lib

# %%
from pycaret.classification import *

# %% [markdown]
# ## initiate the data to inter to machine learning model

# %%
exp_name = setup(data = df,  target = 'rate' , n_jobs= -1,normalize=True,remove_outliers =True , data_split_shuffle =True , use_gpu = True)
# Out:
# <style type="text/css">
# #T_57222_row18_col1, #T_57222_row29_col1, #T_57222_row40_col1, #T_57222_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_57222">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57222_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_57222_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57222_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57222_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_57222_row0_col1" class="data row0 col1" >6280</td>
#     </tr>
#     <tr>
#       <th id="T_57222_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57222_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_57222_row1_col1" class="data row1 col1" >rate</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## comber between sub off models

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_0db87 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## get a lot of information for machin learning model

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## plot the model Accuracy

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'confusion_matrix')

# %% [markdown]
# ## use calssical machine learning alogrithm

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,shuffle =True ,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, fbeta_score, confusion_matrix
# Out:
# C:\Users\7ouda\anaconda3\envs\tensorflow\lib\site-packages\xgboost\compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
models = {
    'LR': LogisticRegression(),
    'KNN': KNeighborsClassifier(),
    'DT': DecisionTreeClassifier(),
    'RF': RandomForestClassifier(),
    'XGB': XGBClassifier()
}

# %%
for name, model in models.items():
    print(f'Model: {name}')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Confusion Matrix\n{confusion_matrix(y_test, y_pred)}')
    print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Recall: {recall_score(y_test, y_pred)}')
    print(f'Precession: {precision_score(y_test, y_pred)}')
    print(f'F1: {f1_score(y_test, y_pred)}')
    print(f'FBeta_0.5: {fbeta_score(y_test, y_pred, beta=0.5)}')
    print(f'FBeta_2: {fbeta_score(y_test, y_pred, beta=2)}')
    print('-'*80)
# Out:
# Model: LR
# C:\Users\7ouda\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\7ouda\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Confusion Matrix
# [[5952  450]
#  [1340 2602]]
# Accuracy: 0.826952822892498
# Recall: 0.6600710299340437
# Precession: 0.8525557011795544
# F1: 0.7440663425793537
# ...

# %% [markdown]
# ##  DecisionTreeClassifier is the best Classifier get 97% Accuracy

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

param_dist = {"max_depth": [3, None],
              "max_features": randint(1, 9),
              "min_samples_leaf": randint(1, 9),
              "criterion": ["gini", "entropy"]}

tree = DecisionTreeClassifier()

tree_cv = RandomizedSearchCV(tree, param_dist, cv=5)

tree_cv.fit(x,y)

print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 1}
# Best score is 0.882514873257926
